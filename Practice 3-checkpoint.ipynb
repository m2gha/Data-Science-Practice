# %%
import pandas as pd
df=pd.read_csv('pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
new_df=df.loc[(df['Type 1']=='Grass')| (df['Type 2']=='Poison')]

# %%
new_df
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                 Weedle    Bug    Poison   40      35       30
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
new_dfa=df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]

# %%
new_dfa
# Out:
#        #                   Name Type 1  Type 2  Speed  Speed   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison     45     45   45      49
# 1      2                Ivysaur  Grass  Poison     60     60   60      62
# 2      3               Venusaur  Grass  Poison     80     80   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison     80     80   80     100
# 48    43                 Oddish  Grass  Poison     30     30   45      50
# 49    44                  Gloom  Grass  Poison     40     40   60      65
# 50    45              Vileplume  Grass  Poison     50     50   75      80
# 75    69             Bellsprout  Grass  Poison     40     40   50      75
# 76    70             Weepinbell  Grass  Poison     55     55   65      90
# 77    71             Victreebel  Grass  Poison     70     70   80     105
# 344  315                Roselia  Grass  Poison     65     65   50      60
# 451  406                  Budew  Grass  Poison     55     55   40      30
# ...

# %%
new_dfa=df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['HP']>70)]

# %%
new_dfa
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 50        90     50           1      False
# 77        70     70           1      False
# 652       80     30           5      False

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# filter out all entries with speed > 10
new_dfaspeed=df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison') & (df['Speed']>10)]

# %%
new_dfaspeed
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
#filter attack > 50 AND Type 2 fairy AND speed > 100
new_dfaf=df.loc[(df['Type 2']=='Fairy') & (df['Speed']>100) & (df['Attack']>50)]

# %%
new_dfaf
# Out:
#        #                 Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 607  547           Whimsicott     Grass  Fairy  60      67       85       77
# 772  702              Dedenne  Electric  Fairy  67      58       57       81
# 796  719  DiancieMega Diancie      Rock  Fairy  50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# 607       75    116           5      False
# 772       67    101           6      False
# 796      110    110           6       True

# %%
# save the filtered result into a new file 
new_df.to_csv('filtered_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nv/v34jn8hj5llb51ndbwprvb900000gn/T/ipykernel_20265/1776242030.py in <module>
#       1 # save the filtered result into a new file
# ----> 2 new_df.to_csv('filtered_data.csv')
#
# NameError: name 'new_df' is not defined

# %%
#you can either reset the index or drop it
new_df=new_df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nv/v34jn8hj5llb51ndbwprvb900000gn/T/ipykernel_20265/3062330957.py in <module>
#       1 #you can either reset the index or drop it
# ----> 2 new_df=new_df.reset_index()
#
# NameError: name 'new_df' is not defined

# %%
#to get rid of the old one 
new_df = new_df.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/nv/v34jn8hj5llb51ndbwprvb900000gn/T/ipykernel_20265/129467448.py in <module>
#       1 #to get rid of the old one
# ----> 2 new_df = new_df.reset_index(drop=True)
#
# NameError: name 'new_df' is not defined

# %%
#same advanced filtering
#search for all rows that contain the key "Mega"
df.loc[df["Name"].str.contains('Mega')]
#NOTE that contains is not the same as ==
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
#or NOT containing Mega
df.loc[~df["Name"].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
#move speed in df to the beginning of the columns of force
cols=list(df.columns)

# %%
df = df[cols[0:4]+[cols[-3]]+cols[4:12]]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Speed  Speed  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison     45     45  45      49
# 1      2                Ivysaur    Grass  Poison     60     60  60      62
# 2      3               Venusaur    Grass  Poison     80     80  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison     80     80  80     100
# 4      4             Charmander     Fire     NaN     65     65  39      52
# ..   ...                    ...      ...     ...    ...    ...  ..     ...
# 795  719                Diancie     Rock   Fairy     50     50  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy    110    110  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost     70     70  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark     80     80  80     160
# 799  721              Volcanion     Fire   Water     70     70  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Speed  Generation  Legendary
# ...

# %%
#Regular Expression (super powerfull in complex filtering) Regex engine
import re
df.loc[df['Type 1'].str.contains('Fire'||'Grass',regex=True) #or not working with str.contains
# Out:
#   File "/var/folders/nv/v34jn8hj5llb51ndbwprvb900000gn/T/ipykernel_19936/298062381.py", line 3
#     df.loc[df['Type 1'].str.contains('Fire'||'Grass',regex=True)
#                                             ^
# SyntaxError: invalid syntax

# %%
#overlook or drop caps
df.loc[df['Type 1'].str.contains('fire || grass',flags=re.I,regex=True)]#or not working with str.contains
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#filter out all names that start with pi followed or not by a on or more symbol
df.loc[df['Name'].str.contains('^pi[a-z]*',flags = re.I, regex=True)]
# extremely important
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
df.loc[df["Type 2"].str.contains("^F[a-z]*",na=False,flags=re.I,regex=True)]
# Out:
#        #                       Name  Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard    Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y    Fire  Flying   78     104       78
# 15    12                 Butterfree     Bug  Flying   60      45       50
# 20    16                     Pidgey  Normal  Flying   40      45       40
# 21    17                  Pidgeotto  Normal  Flying   63      60       55
# ..   ...                        ...     ...     ...  ...     ...      ...
# 773  703                    Carbink    Rock   Fairy   50      50      150
# 777  707                     Klefki   Steel   Fairy   57      80       91
# 793  717                    Yveltal    Dark  Flying  126     131       95
# 795  719                    Diancie    Rock   Fairy   50     100      150
# 796  719        DiancieMega Diancie    Rock   Fairy   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# repeat regex
import re
df.loc[df['Type 1'].str.contains('Fire', regex=True)] #worked
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire',regex = True) | df['Type 1'].str.contains('Grass',regex = True)]#or in here worked perfectly
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass',flags=re.I,regex=True)]#or in here too worked
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
#conditional changes / very important 
df.loc[df['Type 1']=='Fire','Legendary'] = True

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#conditional subsitute
df.loc[df['Type 1']=='Grass','Type 1'] = 'ONFlame'

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur  ONFlame  Poison  45      49       49
# 1      2                Ivysaur  ONFlame  Poison  60      62       63
# 2      3               Venusaur  ONFlame  Poison  80      82       83
# 3      3  VenusaurMega Venusaur  ONFlame  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#condition mutli changes
df.loc[df['Speed']>70,['Generation','Legendary']] = ['TESTA','']

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur  ONFlame  Poison  45      49       49
# 1      2                Ivysaur  ONFlame  Poison  60      62       63
# 2      3               Venusaur  ONFlame  Poison  80      82       83
# 3      3  VenusaurMega Venusaur  ONFlame  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary
# 0         65       65     45          1     False
# ...
